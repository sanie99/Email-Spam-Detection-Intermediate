# %%
import pandas as pd

# %%
data = pd.read_csv('../data/raw/email_dataset_classification.csv')
print(data.head())
# Out:
#    Unnamed: 0                                            message  label
# 0           0  ['Fabulous discounts from CanadianPharmacy. 50...      1
# 1           1                      http://houston.cowparade.net/      0
# 2           2  =================================\n\nGuarantee...      1
# 3           3  Thanks for your help! ----------------------  ...      0
# 4           4  Start Date: 10/13/01; HourAhead hour: 23; No a...      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298166 entries, 0 to 298165
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  298166 non-null  int64
#  1   message     298166 non-null  object
#  2   label       298166 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 6.8+ MB

# %%
data.shape
# Out:
# (298166, 3)

# %%
data['label'].value_counts()
# Out:
# label
# 0    208716
# 1     89450
# Name: count, dtype: int64

# %%
data = data.drop(['Unnamed: 0'], axis=1)
print(data.head())
# Out:
#                                              message  label
# 0  ['Fabulous discounts from CanadianPharmacy. 50...      1
# 1                      http://houston.cowparade.net/      0
# 2  =================================\n\nGuarantee...      1
# 3  Thanks for your help! ----------------------  ...      0
# 4  Start Date: 10/13/01; HourAhead hour: 23; No a...      0

# %%
data.to_csv('../data/processed/cleaned_email_dataset_classification.csv', index=False)
print("Cleaned data saved successfully!")
# Out:
# Cleaned data saved successfully!
